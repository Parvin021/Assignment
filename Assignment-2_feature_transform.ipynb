# %% [markdown]
# <a href="https://colab.research.google.com/github/Parvin021/Assignment/blob/main/Assignment-2_feature_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('supershops.csv')

# %%
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.dropna()
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dropna().shape
# Out:
# (49, 5)

# %%
#df = df.dropna()
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # MinMaxScaler / Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler()

# %%
df['Marketing Spend'] = m.fit_transform(df[['Marketing Spend']]) # fit() = training the model ; transform() = replace the values

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
ad = m.fit(df[['Administration']])

# %%
ad
# Out:
# MinMaxScaler()

# %%
df.head() # no changes
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration_Transform'] = m.transform(df[['Administration']])

# %%
df['Administration_Transform'].head()
# Out:
# 0    0.651744
# 1    0.761972
# 2    0.379579
# 3    0.512998
# 4    0.305328
# Name: Administration_Transform, dtype: float64

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
#
#    Administration_Transform
# 0                  0.651744
# 1                  0.761972
# 2                  0.379579
# 3                  0.512998
# 4                  0.305328

# %% [markdown]
# # Standardization

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
df3["Marketing Spend"]= std.fit_transform(df3[['Marketing Spend']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df3["Administration"]= std.fit_transform(df3[['Administration']])

# %%
df3.head(20)
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0          0.897913        0.560753  471784.10    Dhaka  192261.83
# 1          1.955860        1.082807  443898.53      Ctg  191792.06
# 2          1.754364       -0.728257  407934.54  Rangpur  191050.39
# 3          1.554784       -0.096365  383199.62    Dhaka  182901.99
# 4          1.504937       -1.079919  366168.42  Rangpur  166187.94
# 5          1.279800       -0.776239  362861.36    Dhaka  156991.12
# 6          1.340066        0.932147  127716.82      Ctg  156122.51
# 7          1.245057        0.871980  323876.68  Rangpur  155752.60
# 8          1.030369        0.986952  311613.29    Dhaka  152211.77
# 9          1.091819       -0.456640  304981.62      Ctg  149759.96
# 10         0.620398       -0.387599  229160.95  Rangpur  146121.95
# 11         0.593085       -1.065540  249744.55      Ctg  144259.40
# 12         0.443260        0.215449  249839.44  Rangpur  141585.52
# ...

# %% [markdown]
# # Max Abs Scaler

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MaxAbsScaler.html

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
abs=MaxAbsScaler()

# %%
df4["Marketing Spend"] = abs.fit_transform(df4[["Marketing Spend"]])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Robust Scaler

# %%
# video: https://youtu.be/U9N-ELpCpc8
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MaxAbsScaler.html

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import RobustScaler

# %%
rob=RobustScaler()

# %%
df5["Marketing Spend"]=rob.fit_transform(df5[["Marketing Spend"]])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Max

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
max_val = df6['Marketing Spend'].max()

# %%
max_val
# Out:
# 165349.2

# %%
df6['Marketing Spend'] = df6['Marketing Spend'] / max_val

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
